# %% [markdown]
# <h1>PySomani Discovery 2 | <b>Bonus Challenge</b></h1>
#
# Are you up for the challenge? See if you can complete the following coding puzzles!

# %% [markdown]
# # **Puzzle 1** | Mailing address
#
# Canada Post wants your help asked to write a program that prints out mailing addresses.
#
# Write some code in the cell below that defines variables for a person's **first name**, **last name**, **street address**, **city**, **province** and **postal code**. Assign realistic values to each of your variables. Print out the address so that it matches the following format:
#
# ```
# Ianos Popadopoulos
# 235 West 18th Street
# North Vancouver, BC V7M 1W7
# ```

# %%
# Code your solution to Puzzle 1 below. When you run this cell, it should print
# the recipient address that matches the format of what's shown above.

# %% [markdown]
# # **Puzzle 2** | Variable inspector
#
# Code a simple variable inspector that looks at a variable called ``myVariable`` and prints out a sentence stating its variable type and the value it contains.
#
# > **Extra points!**
# > Use the ``%`` operator to embed the variable type and value in your sentence.

# %%
# Code your solution to Puzzle 2 below. When you run this cell, it should print
# a single sentence that displays the variable type and value of myVariable.

# %%
# BONUS! Find a second way to solve the same problem. At least one of the two 
# solutions must use the % operator.

# %% [markdown]
# # **Puzzle 3** | Repeater
#
# Define a variable and assign it a value. Write a **single line of code** that prints out the value of the variable _repeated as many times as the length of the variable_ on a single line. Make sure that the repetitions have space betwen them. The same code needs to work with a variable that could be a **string**, **int** or **float** value.
#
# Here are three examples showing variable values and the expected output:
# ```
# myVar = 'hello'
#
# hello hello hello hello hello
# ```
#
# ```
# myVar = 10
#
# 10 10
# ```
#
# ```
# myVar = 3.14159
#
# 3.14159 3.14159 3.14159 3.14159 3.14159 3.14159 3.14159
# ```
#
# > **HINT:**
# > To find the length of a variable called ``myString``, use ``len(myString)``.

# %%
# Code your solution to Puzzle 3 below. When you run this cell, it should print
# the value of the variable you define, repeated as many times as the length of 
# the value. (See the examples shown above.)
