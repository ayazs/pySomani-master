# %% [markdown]
# <h1>PySomani Discovery 6 | <b>Bonus: Turtle Solver</b></h1>
#
# Are you up for this challenge? Use turtle's capabilities to solve the following puzzles.
#
# >**NOTE:** To get started, be sure to run the cell below to install and import ColabTurtle.<br/>
# >_You will need to run this every time you open this notebook or reset the runtime._

# %%
# Call the PyPi installer to find and install the latest version of ColabTurtle.
# !pip3 install ColabTurtle

# Use a variation of the import statement so we can access the Turtle module.
from ColabTurtle import Turtle as turtle

# %% [markdown]
# # **Puzzle 1** | Drawing rectangles
#
# You've already coded functions to draw regular triangles, squares and polygons, all of which have sizes of the same length. In this puzzle, you will code a function that draws a rectangle.
#
# Your ``draw_rectangle()`` function must take the following parameters:
#
# * **width**: the width of the rectangle in units;
# * **height**: the height of the rectangle in units;
# * **colour**: colour of the rectangle;
# * **turn**: how many degrees turtle should turn right before drawing;
# * **location**: the (x,y) location where turtle must draw the rectangle.
#
# Also, function must **return** the area of the rectangle in square units. Don't forget to assign default values to the parameters so that someone can simply call ``rectangle()`` without parameters to have a standard rectangle drawn!

# %%
# Code your solution to Puzzle 1 below. Use this cell to define the function, and
# run the next cell to test it out.

# %%
# Test your function by running this cell. If successful, it should produce some 
# lovely rectangle art!
import random

# Start will a clean canvas and make turtle move at max speed
turtle.initializeTurtle(initial_speed=10, initial_window_size=(800, 500))

# Test drawing a rectangle using the default parameters
area = draw_rectangle()
print("Area of the default rectangle: %i units squared" % area)

# Use draw_rectangle() to make a colourful forest of 50 rectangles!
for count in range(50) :
  draw_rectangle(width=random.randint(20,60),
                 height=random.randint(20,60),
                 colour=turtle.VALID_COLORS[random.randint(0,len(turtle.VALID_COLORS)-2)],
                 turn=random.randint(15,30),
                 location=(random.randint(120,680), random.randint(120,380)))

# %% [markdown]
# # **Puzzle 2** | Circle maker
#
# So far, all of the shapes we have drawn have straight edges. But what if you want to draw a circle?
#
# This puzzle is to code a ``draw_circle()`` function that will draw a circle of a given colour, starting from a specific location. Your function should take the following parameters:
#
# * **colour**: colour of the circle;
# * **location**: the (x,y) location where turtle must draw the circle.
#
# Your function does not return any value. Make sure you assign default values to the parameters.
#
# > **Extra points!**
# > After completing and testing your ``draw_circle()`` function, add a **size** parameter that draws a bigger circle when it's value is bigger (and smaller when the value is smaller). It's up to you to decide how the value of ``size`` coresponds to the actual circle.

# %%
# Code your solution to Puzzle 2 below. Use this cell to define the function, and
# run the next cell to test it out.

# %%
# Test your function by running this cell.

import random

# Start will a clean canvas and make turtle move at max speed
turtle.initializeTurtle(initial_speed=10, initial_window_size=(800, 500))
turtle.hideturtle()

# Test drawing some circles
turtle.bgcolor('white')
draw_circle(colour='red', location=(180, 200))
draw_circle(colour='green', location=(300, 200))
draw_circle(colour='blue', location=(420, 200))

# %%
# EXTRA POINTS TEST: If you added the size parameter, run this test to see if it 
# worked.
# Start will a clean canvas and make turtle move at max speed
turtle.initializeTurtle(initial_speed=10, initial_window_size=(800, 500))
turtle.hideturtle()

for count in range(3) :
  draw_circle(size=(count + 1),
              colour=turtle.VALID_COLORS[count],
              location=(300 + 5 * count, 250 - 8 * count))

# %% [markdown]
# # **Puzzle 3** | Triangle calculator
#
# In this puzzle, you and turtle need to make a function that draws an _isoceles_ triangle &ndash; that is a triangle with two sides of the same length and a third side that is different. Your function will be given the lengths of the sides, but you will have to rely on turtle's capabilities to figure out how to draw the triangle.
#
# Your function will take two parameters and return nothing:
# * **base_length**: The length of the base of the isoceles triangle
# * **side_length**: The length of the two other sides of the traingle (which are equal)
#
# The challenge in this problem is _not_ to use math formulae to calculate the angles, but rather to code an algorithm that uses a **while-loop** to accomplish the task.
#
# Here are a few hints to help you get started:
#
# * Recall that an isoceles triangle has two sides of equal length **and** two angles that are equal to each other.
# * Your function is given the lengths of all three sides of the triangle. What you don't know are the angles of the triangle.
# *  Remember, two of your unknown angles are equal and all angles in a triangle always add up to 180&deg;.
# * The starter code draws the base line and gives you the left and right corner locations on the canvas (as ``point_left`` and ``point_right``).
# * Use a while-loop to try drawing the triangle sides starting at the corner locations using different angles. You'll know that you have found the correct angle when the end points of the two lines meet at the same point.
# * The current location of turtle at any time is in the ``turtle.turtle_pos`` variable.

# %%
# Code your solution to Puzzle 3 below. Define the function here, and run the 
# next cell to test it out. 
#
# The beginnig of the function is gien to help you get started.

def calculate_triangle(side_length, base_length) :

  # Initialize the canvas and max the turtle's speed
  turtle.initializeTurtle(initial_speed=10, initial_window_size=(800, 500))

  # Draw the base of the triangle centred to the canvas 
  # and save the bottom corner locations of the triangle.
  turtle.penup()
  turtle.goto(int(round((800 - base_length) / 2)), 400)

  # Save the bottom left point of the triangle
  point_left = turtle.turtle_pos
  
  # Draw the triangle base in yellow
  turtle.pendown()
  turtle.color('yellow')
  turtle.goto(int(round((800 + base_length) / 2)), 400)

  # Save the bottom right point of the triangle
  point_right = turtle.turtle_pos

  ### ADD YOUR CODE BELOW ###

# %%
def calculate_triangle(side_length, base_length) :

  # Initialize the canvas and max the turtle's speed
  turtle.initializeTurtle(initial_speed=10, initial_window_size=(800, 500))

  # Draw the base of the triangle centred to the canvas 
  # and save the bottom corner locations of the triangle.
  turtle.penup()
  turtle.goto(int(round((800 - base_length) / 2)), 400)

  # Save the bottom left point of the triangle
  point_left = turtle.turtle_pos
  
  # Draw the triangle base in yellow
  turtle.pendown()
  turtle.color('yellow')
  turtle.goto(int(round((800 + base_length) / 2)), 400)

  # Save the bottom right point of the triangle
  point_right = turtle.turtle_pos

  ### SOLUTION CODE BELOW ###
  turtle.hideturtle()
  turtle.color('grey')
  point_tl = (point_left[0], 0)
  point_tr = (point_right[0], 0)
  test_angle = int(round((89 - 1) / 2))
  angle_range = int(round(test_angle / 2))

  while angle_range > 0 :
    # Turtle is at point_right
    turtle.left(test_angle)
    turtle.forward(side_length)
    point_tr = turtle.turtle_pos

    turtle.penup()
    turtle.goto(int(point_left[0]), int(point_left[1]))
    turtle.right(test_angle)
    turtle.pendown()

    # Turtle is at point_left
    turtle.right(test_angle)
    turtle.forward(side_length)
    point_tl = turtle.turtle_pos

    turtle.penup()
    turtle.goto(int(point_right[0]), int(point_right[1]))
    turtle.left(test_angle)
    turtle.pendown()

    if (point_tl[0] < point_tr[0]) :
      test_angle = test_angle + angle_range
    elif (point_tl[0] > point_tr[0]) :
      test_angle = test_angle - angle_range
    else :
      break

    angle_range = int(round(angle_range / 2))


  turtle.color('yellow')
  turtle.goto(int(point_tr[0]), int(point_tr[1]))
  turtle.goto(int(point_left[0]), int(point_left[1]))

# %%
# Test your solution by running this code cell. If you have succeeded, it should 
# draw a random isoceles triangle.
import random

base = random.randint(4,780)
side = random.randint(int(round(base / 2) + 1), 400)

calculate_triangle(side, base)

print("base=%i, side=%i" % (base, side))
