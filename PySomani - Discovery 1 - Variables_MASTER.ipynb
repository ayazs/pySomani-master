# %% [markdown]
# <h1>PySomani Discovery 1 | <b>Venturing into variables</b></h1>
#
# **Welcome to your first discovery unit!** In this unit we will talk about what coding is all about and take our first steps in Python by learning how to use variables.
#
# Before getting started, make sure that you have already followed the steps in the PySomani SETUP notebook. If you have not yet done so, open that notebook and run each of the cells to create the PySomani folders and pull down the files.

# %% [markdown]
# # About Colab notebooks

# %% [markdown]
# This is a Colab notebook, which is Google's implementation of Jupyter. A notebook combines text and code together so that you can organize your coding ideas and experiment with them.
#
# We'll use Colab to learn more about programming in Python. Watch this [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more about how it works.

# %% [markdown]
# # What is coding?

# %% [markdown]
# Coding (also called programming) is how you instruct a computer to do something useful. There are many programming languages used in coding; you are already familiar with Scratch and you might also have heard of others like Javascript, Java, PHP, C++,... (I could go on for a long time!)
#
# Just like the languages we speak, each programming langauge is a bit different from the others but they all have certain fundamentals that allow you to do the same thing. We are learning to code in **Python**, but the coding skills you will learn can easily be transfered to most other programming languages.
#
# ## Why Python?
# So why are we using Python to learn coding, and not one of the many other languages listed above? For one, Python is perhaps the most popular programming language out there right now. Because of its powerful math libraries, it is widely used in cutting-edge fields of machine language and artificial intelligence.
#
# Most importantly for our purposes, Python is flexible and structured, which makes it very easy to get started with coding.
#
# I'll prove it to you! Follow the exercise below to write your first bit of Python code.

# %% [markdown]
# # Hello World!

# %% [markdown]
# It's traditional when you are learning a new programming language that the first thing you do is write a program that prints out:
#
# > Hello world!

# %% [markdown]
# <h4>Exercise 1</h4>
# Type out this line of code into the code cell below. Then run the code cell.
#
# ```
# print('Hello world!')
# ```
# > **Did you know?**
# > *In Python, anything written after a hash (#) sign is a comment, and is ignored by the Python interpreter.*

# %%
# Copy the line of code above below. Then press the "play" button on the left to run this cell

# %% [markdown]
# Well done! You have just written your first bit of Python code.
#
# In coding, almost every program is about instructing a computer to store and organize information, then to perform some actions with that information before making something really interesting happen. So before we can get to the "really interesting" part, we first need to learn the basics!
#
# Variables are the main way that programming languages store and organize information. We'll start there.

# %% [markdown]
# # **Variables**
# Every programming language provides variables, which are sometimes just called "vars". Vars are important because they allow the programmer to keep a handle on the data and objects used in their computer program.
#
# One easy way to understand a **var** is to think of it as a box. Computer programs have lots of things that need to be kept organized, and each var is like a labelled box that you can put somthing in.

# %% [markdown]
# Here's a variable named ``greeting`` that holds the text ``'Hello'``:

# %%
greeting = 'Hello'

# %% [markdown]
# Here's another var called `myNumber` that's initialized to hold Zayn's favourite number:

# %%
myNumber = 4

# %% [markdown]
# Here's a var holding another number:

# %%
anotherVar = 9

# %% [markdown]
# Vars can be combined to create other values.
#
#
# > *Click the play button to the left of the code cell below to run the code. Did you get an error? That's probably because you need to run the code cells above first. Otherwise, the vars referred to below will not have been initialized.*

# %%
myNumber + anotherVar

# %% [markdown]
# <h4>Exercise 2</h4>
# Write your own code that performs some operations with the vars as instructed below.
#
# > **Don't forget!** *In Python, anything written after a hash (#) sign is a comment, and is ignored by the Python interpreter.*

# %%
# Write a line of code to change myNumber to your favorite number

# %%
# Multiply myNumber with anotherVar (using *)

# %%
# Now subtract myNumber from anotherVar (using -)

# %%
# Create a variable named 'blurp' (without the quotation marks) that stores the 
# result of dividing 1 by anotherVar (using /)

# %%
# Now multiply myNumber, anotherVar and your variable above together. What do 
# you notice about the answer?
## (Hint: if you have performed the steps correctly, you should see your 
## favourite number displayed again!)

# %% [markdown]
# # **Types of variables**
# So far, we've talked about variables being like boxes that have names. You saw how you can store values inside them and manipulate them. **Type** is another important property of a variable.
#
# When you first assign a value to a variable, the var takes on the *type* of the value that has been assigned to it. Type refers to the kind of value that a variable stores and helps Python determine how to represent it in the computer's memory (so that you don't have to worry about that kind of thing!)
#
# Each of the variables in Exercise 2 is a number, but Python distinguishes between different types of numbers.

# %%
# Run this code to see what type of variable myNumber is

type(myNumber)

# %% [markdown]
# ## Numeric types
# If the code ran correctly, it should have printed 'int'. But what is an *int*?
#
# Int is short for 'integer', which is a fancy word to describe all whole numbers from negative infinity to positive infinity. Integers are numbers like **1**, **7**, **19**, and **26 083 395**. They also include the number **0** and all whole negative numbers like **-28**, **-1**, **-9 563**.
#
# So what kind of number is not an interger? Any non-whole number that must be expressed as a decimal like **7.3**, **-93.60758**, or **0.3147329**. Fractions, like $\frac{1}{3}$ and $-\frac{2}{7}$ are also not stored as *int* variables.
#
# So if these non-whole numbers are not of type *int*, then what are they? Write some code below to discover the answer.

# %% [markdown]
# <h4>Exercise 3 </h4>
#
# Use the ``type()`` function to write code that reveals the types of the variables we saw above.

# %%
# What variable type is anotherVar ?

# %%
# Can you guess what type greeting is? Write code to find out.

# %%
# What about the type of the blurp var?

# %% [markdown]
# From the results of your code above, you will have discovered a few different variables types: **int**, **str** and **float**.
#
# We've already discussed ``int``. The ``float`` type is another number type that is used to hold the kinds of non-whole numbers that we talked about above.
#
# The third variable type that we've discovered in Exercise 3 is ``str``, which is short for "string". A string is a variable that holds a string of characters, like a word a sentence or even an entire text document.

# %% [markdown]
# # **What's Next**
#
# Well done completing this discovery notebook. In **PySomani Discovery 2 | Struting with strings**, we will learn some cool things about how string variables work.

# %% [markdown]
# Run the cell below to copy the files you will need to start the next discovery.

# %%
# %%bash
# rootdir="/content/gdrive/My Drive"
# psdir="$rootdir/PyS"
#
# reponame="pySomani"
# gitdir="$psdir/$reponame"
#
# cpdir_array=(discovery_02)
# cpf_array=(PySomani-SETUP-UPDATE.ipynb)
#
# for d in "${cpdir_array[@]}"; do cp -v "$gitdir/$d/"* "$psdir"; done
# for f in "${cpf_array[@]}"; do cp -v "$gitdir/"$f "$psdir"; done

# %% [markdown]
# You are now ready to begin your discovery!
#
# > **Open the next notebook:**
# > In your Google Drive ``My Drive``, find the ``PyS`` folder and open the Colab notebook called ``PySomani - Discovery 2 - Strings.ipynb``.
