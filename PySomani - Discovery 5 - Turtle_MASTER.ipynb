# %% [markdown]
# <h1>PySomani Discovery 5 | <b>Turtle Tricks</b></h1>
#
# Okay PySomanis, it's time to put our geometry hats on. We're going to be drawing on all of our coding skills to begin drawing all sorts of cool forms! (_See how I did that there?_)
#
# In this discovery we're going to meet the turtle and teach her some tricks. Shall we start with the introductions?

# %% [markdown]
# _This discovery is under development. Come back again soon to discover more!_

# %% [markdown]
# # **Meet the turtle**

# %% [markdown]
# Turtle is an expert at drawing stuff on the screen. You just need to instruct her on what to draw (using Python code).
#
# To get started we need to set her up. Turtle lives in a Python library called ``ColabTurtle``. Run the next cell to install the library and import all of its functionality.

# %%
# Call the PyPi installer to find and install the latest version of ColabTurtle.
# !pip3 install ColabTurtle

# Use a variation of the import statement so we can access the Turtle module.
from ColabTurtle import Turtle as turtle

# %% [markdown]
# Now that ``ColabTurtle`` is installed and imported, run the next cell to see the turtle.

# %%
# Create a new turtle session and clear the canvas
turtle.initializeTurtle()

# %% [markdown]
# There she is! But she's not doing much, is she? Let's tell her to do something.

# %%
turtle.forward(50)

# %% [markdown]
# Okay, she drew a line. Nice. Is that all?

# %%
import random

for n in range(random.randint(7, 12)) :
  if (random.randint(0, 1)) :
    turtle.right(random.randint(10, 170))
  else :
    turtle.left(random.randint(5, 140))
  turtle.color(turtle.VALID_COLORS[random.randint(0, len(turtle.VALID_COLORS) - 1)])
  turtle.speed(random.randint(7, 10))
  turtle.forward(random.randint(10,100))

turtle.color('green')

# %% [markdown]
# As you can see, the turtle has some skills! Let's learn how to harness her abilities to do more interesting things.

# %% [markdown]
# # **Turtle basics**

# %% [markdown]
# You can instruct the turtle to move, draw, turn and change colour. Run the cells below to learn how.

# %% [markdown]
# Let's start by clearing the canvas and positioning the turtle back to the middle using ``inititializeTurtle()``. This function should be called at the start of every turtle coding session, and any time that you want to reset the canvas.

# %%
# Clear the canvas and reset the turtle to the middle.
turtle.initializeTurtle()

# %% [markdown]
# Turtle can move using the ``forward()`` and ``backward()`` functions. You specify the distance in units, which the turtle will translate into screen pixels.
#
# Run the cell below to move the turtle forward by 100 units.

# %%
# Move forward by 100 units
turtle.forward(100)

# %% [markdown]
# To change direction, you tell the turtle to swivel right or left. But how far to the right or left should she turn? You tell her that by specifying the number of _degrees_.
#
# >**What are degrees?**
# >
# >Don't worry if you haven't yet learnt about angles and degrees. When telling the turtle to turn, degrees are just a way to tell it how much to turn.
# >
# >There are 360&deg; in a full turn. That means that if you tell turtle to turn right or left by 360&deg;, it will end up facing the same direction as it was before turning. So if you want her to face backwards, you should turn her half that amount &ndash; that's 180&deg; (360&deg; divided by 2). A quarter turn is 90&deg; (360&deg; divided by 4). You can use the circle diagram below to see how many degrees to specify base on how much you want turtle to turn.
# >
# ><a title="Autiwa / CC BY-SA (https://creativecommons.org/licenses/by-sa/3.0)" href="https://commons.wikimedia.org/wiki/File:Rapporteur.svg"><img width="384" alt="There are 360 degrees in a full rotation." src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Rapporteur.svg/256px-Rapporteur.svg.png"></a>

# %%
# Let's turn turtle to the left by 90 degrees...
turtle.left(90)

# ...and move forward by 50 units
turtle.forward(50)

# %% [markdown]
# <h4>Exercise 24</h4>
#
# Now it's your turn to practice turning and moving turtle.

# %%
# Write code to turn turtle right by 30 degrees



# Move her forward by 25 units

# %%
turtle.right(30)
turtle.forward(25)
turtle.right(150)
turtle.forward(50)

# %%
# Write code to make the turtle turn right 150 degrees. Then move forward by 50 units.

# %% [markdown]
# Good work moving turtle around. Now let's make her draw in colour.
#
# To change turtle's colour, use the ``color()`` function. (Note that the function name uses the American spelling of "colour".) You tell turtle which colour my passing the name of the colour as a string. Here are the valid colours that turtle can accept:
# ```python
# ('white', 'yellow', 'orange', 'red', 'green', 'blue', 'purple', 'grey', 'black')
# ```
# So to set the turtle's colour to green, call ``turtle.color('green')``.

# %%
# Write code to set turtle to any colour of your choice (other than black).




# Now turn turtle to the right by 90 degrees, and move her forward by 14 units.

# %% [markdown]
# Sometimes we want turtle to move without drawing a line. Call ``penup()`` to instruct turtle to lift her pen. She'll continue to follow all commands after that without drawing anything until you call ``pendown()``.

# %%
# Use turtle.penup() to make turtle lift her pen and stop drawing.



# Now write some code to move turtle back to the centre postition of the screen.
# You will need to use forward() and left() to get there, but it's up to you to
# figure out how many units to move and degrees to turn.

# %% [markdown]
# Let's get turtle to skate backwards. Use ``turtle.backward()`` instead of ``forward()`` to complete the instructions below. Remember that just like with ``forward()`` you pass the distance in number of units to ``backward()``.

# %%
# Put the pen down again and make turtle move backwards by 50 units.

# %%
# Tell turtle to turn right by 30 degrees, then move backwards by 25 units.

# %%
# Finally make turtle turn right by 60 degrees and move backward by 100 units.

# %% [markdown]
# # **Making shapes**

# %% [markdown]
# Now that you know the turtle basics, let's learn to draw some shapes.
#
# The kind of shape we want to draw are regular shapes &ndash; those that have a specific number of straight sides of equal length. Another word for this kind of shape is a _polygon_.
#
# The first polygon that we will draw is a square. Before we start, it's useful to remind ourselves of the characteristics of the polygon we are drawing and decide on some things like the length of the sides and the colour.
#
# * How many sides does this polygon have?
# * How long do we want each side to be? (in units)
# * How many corners will this shape have?
# * How many degrees will the turtle need to turn at each corner?
# * What colour do we want the shape be?

# %% [markdown]
# After answering these questions, we're ready to write some code.

# %%
# Let's define some variables based on our answers to the above questions.
square_sides = 4  # Number of sides in a square
side_length = 50  # Set this to however long we want each side to be
corners = 4       # Number of corners in a square
square_turn = 90  # Number of degrees that the turtle needs to turn at each corner
side_colour = 'blue'  # The colour we've chosen for our square.

# Start by clearning the canvas
turtle.initializeTurtle()

# Set the colour
turtle.color(side_colour)

# Now let's draw the first side of the square
turtle.forward(side_length)

# Turn left at the first corner
turtle.left(square_turn)

# Draw the second side of the square
turtle.forward(side_length)

# What's next?

# %% [markdown]
# Nicely done! We've programmed turtle to draw a perfect square.

# %% [markdown]
# <h4>Exercise 25</h4>
#
# Now it's your turn. Write some code below to program the turtle to draw a triangle.
#
# Start by asking the same questions as we did above: _how many sides?_ _how long should each side be?_ _what colour should the shape be?_ _how many degrees does the turtle need to turn at each corner?_

# %%
# Define your variables based on the shape you are drawing.
triangle_sides =    # Number of sides in a triangle
side_length =       # Set this to however long you want each side to be
corners =           # Number of corners in a triangle
triangle_turn =     # Number of degrees that the turtle needs to turn at each corner
side_colour =       # The colour you want for your triangle.

# Start by clearning the canvas
turtle.initializeTurtle()

# Set the colour
turtle.color(side_colour)

# Now write the code to draw your triangle

# %% [markdown]
# ## Shapes and loops
#
# Have a look at the code that we've written for square and triangle. Could have used our coding knowledge to accomplish the same thing with fewer lines of code?
#
# You probably noticed that we defined a few variables that we didn't end up using, and that there is a lot of repeted code. Ignore the extra variables for the moment &ndash; let's see what we can do to get rid of that repeated code.
#
# In our last discovery, we learnt how to use for-loops and while-loops to make Python repeat our instructions. We can use a loop here to make coding the square less repetitious.

# %%
# These are the variables we defined for the square.
square_sides = 4  # Number of sides in a square
side_length = 50  # Set this to however long we want each side to be
corners = 4       # Number of corners in a square
square_turn = 90  # Number of degrees that the turtle needs to turn at each corner
side_colour = 'yellow'  # The colour we've chosen for our square.

# Start by clearning the canvas
turtle.initializeTurtle()

# Set the colour
turtle.color(side_colour)

# %% [markdown]
# So far, so good. Looking back at our square code above, what part of it was repeated over and over again?
#
# Of course, it was drawing the side and turning the corner. Let's use a for-loop to accomplish the repetition.

# %%
# We need to repeat the loop enough times to draw each side of our square
for count in range(4) :
  # Draw a side
  turtle.forward(side_length)

  # Turn left at the corner
  turtle.left(square_turn)

# %% [markdown]
# Look at that &ndash; we just reduced eight lines of code to three by using a for-loop. See if you can do the same below for your triangle code.

# %% [markdown]
# <h4>Exercise 26</h4>
#
# Copy your triangle code from the previous exercise into the cell below. Then replace the repetitious part of the code with a for-loop, like we did for the square above.

# %%
# Copy your triangle code and paste it below. Then alter it to use a for-loop.

# %% [markdown]
# ## Polygon machine
#
# With your ability to draw a perfect square and a perfect triangle, you are now capable for writing code that can draw any regular polygon. To see how that can be accomplished, take a closer look at the similarities and differences between your code for drawing each shape.
#
# | |Triangle|Square|...|Pentagon|Hexagon|
# |---|---|---|---|---|---|
# |sides|3|4|...|5|6|
# |loop count|3|4|...|**?**|**?**|
# |corners|3|4|...|5|6|
# |turn (degrees)|120|90|...|**?**|**?**|
# |turn x corners|120 x 3 = 360|90 x 4 = 360|...|**?** x 5 = 360|**?** x 6 = 360|
#
# * What patterns do you notice?
# * Could these patterns extend to polygons with more than four sides? (_e.g. pentagons, hexagons, heptagons, octagons, nonagons..._)

# %% [markdown]
# <h4>Exercise 27</h4>
#
# Complete the code below to construct a polygon machine, which can draw any regular polygon of any number of sides.
#
# When switching between polygons, the code must not change. All you should need to do is set the variables correctly at the top, and the polygon machine will draw the desired polygon.

# %%
# Set these variables for the polygon you want to draw.
poly_sides = 3      # Number of sides in the polygon
side_length = 20    # Set this to however long we want each side to be
corners = 3         # Number of corners in the polygon
poly_turn = 120     # Number of degrees that the turtle needs to turn at each corner
side_colour = 'yellow'  # The colour we've chosen for the polygon.

# Start by clearing the canvas
turtle.initializeTurtle()

# Set the colour
turtle.color(side_colour)

# Below, write a loop and block of code to draw the polygon 
# (Hint: You can do this with three lines of code.)

# %% [markdown]
# In the code you wrote above, are there any variables that you did not use? Which ones do you not need at all, and other ones could you somehow replace?
#
# Copy and paste your code from above into the cell below, then modify it to get rid of the variables that are not needed.

# %%
# Copy your code from above and paste it below. Then modify it to remove 
# any unnecessary variables.

# %% [markdown]
# # **Writing a function**

# %% [markdown]
# You have written code that can draw a polygon of any number of sides, of any size. But what if you want to reuse that code to draw different shapes many times over? You would need to copy and paste the code over and over again, changing the variable values each time. There should be a more efficient way to accomplish this.
#
# And there is. Let's learn to write our first function.

# %% [markdown]
# ## What exactly is a function?
#
# You've seen functions and used them. They include ``print()``, ``forward()`` and ``range()``, and they provide useful _functionality_.
#
# But what exactly is a function?
#
# In programing, a function allows your to wrap up a bunch of code into a a single call. You can pass a function _parameters_ and it can pass back a _return value_ when it is done. The best thing about a function is that whoever calls it doesn't need to worry about _how_ it works... they can trust that the function _will work_.
#
# Making a function is actually really easy. Let's have a look...

# %%
# Here is a function that takes a name and a language code, and returns an 
# appropriate greeting.

def universal_greeting(name, language) :
  if language in ('EN', 'en') :
    return "Hello " + name + "!"
  elif language in ('FR', 'fr') :
    return "Bonjour " + name + '!'
  elif language in ('DE', 'de') :
    return "Hallo " + name + '!'
  elif language in ('PT', 'pt') :
    return 'Olá ' + name + '!'
  elif language in ('ES', 'es') :
    return '¡Hola ' + name + '!'
  else :
    return 'Hi ' + name + '.'

# %% [markdown]
# The function above takes two parameters: ``name`` and ``language``. It then uses an ``if``...``elif``...``else`` statment to determine an appropriate greeting message to return. If the language is not recognized, the function returns "Hi _name_."
#
# Let's look at how to call this simple function:

# %%
# Run this cell to test the function and cature it's return value in output.
output = universal_greeting('Nugget', 'es')

# Print output to see what the function returned.
print("The function returned: " + output)

# %% [markdown]
# And _voilà_! We wrote a function.

# %% [markdown]
# <h4>Exercise 28</h4>
#
# Now you are going to write your first function. With the help of turtle, write a function that turns and draws a line of a specified colour. This function will not return a value (functions don't have to return anything), and it will take the following parameters:
#
# * **turn**: how many degrees the turtle will turn before drawing;
# * **size**: the length of the line that will be drawn;
# * **colour**: the colour of the line.
#
# >**HINT:** Don't forget that a function starts with a ``def`` statement that looks like this:
# >```python
# >def my_function(parameter_1, parameter_2, parameter_3) :
# >    # This is where to write the function code....
# >```

# %%
# Write a function that takes (turn, size, and colour) as described above

# %% [markdown]
# After you have written your function, it's important to test that it works. In the code cell below, call your function several times using different choices of _turn_, _size_ and _colour_.
#
# *   Can you select parameters that break your function and cause an error?
# *   How could you change your function to protect it from causing an error?

# %%
# Test your function below by calling it with different parameter values.

# %% [markdown]
# ## Triangle function
#
# We've seen how functions can take parameters and work with that information to do something simple. Now let's develop a function together that will draw a triangle. We'll use what we learnt earlier in this discovery about drawing triangles, and we will see how functions can help us make lots of different triangles.
#
# Let's start by defining a simple triangle drawing function in the cell below.

# %%
# Define a simple function to draw a triangle
def draw_triangle() :
  # Use a loop to draw each side and turn at each corner
  for count in range(3) :
    turtle.forward(30)
    turtle.right(120)

# %%
# Now test the draw_triangle() function by calling it.
draw_triangle()

# %% [markdown]
# It worked! The function drew a simple triangle for us.
#
# But the triangle it drew isn't very interesting, is it? It's small and white... wouldn't it be nice if our function could draw a bigger (or smaller) triangle, in a colour that we choose, and maybe have it point in a direction of our choice?
#
# We can accomplish all this by adding parameters to our ``draw_triangle()`` function. Let's do that below.

# %%
# A function to draw a triangle given the size, colour and how much to turn 
# before starting.
def draw_triangle(side_length, colour, turn) :
  # Set the colour
  turtle.color(colour)
  
  # Turn the turtle right
  turtle.right(turn)

  # Use a loop to draw each side and turn at each corner
  for count in range(3) :
    turtle.forward(side_length)   # Move forward by the given length
    turtle.right(120)

# %%
# Let's test the new draw_triangle() function by calling it a few times.
draw_triangle(60, 'green', 30)

draw_triangle(105, 'blue', 100)

draw_triangle(38, 'yellow', 200)

# %% [markdown]
# Now that is a much cooler function for drawing triangles! Look at all the varieties of triangles we can make! Hey, I bet we could even use the function to make cool patterns &ndash; try running this:

# %%
# Clear the canvas
turtle.initializeTurtle()

# Make a pattern of triangles!
for count in range(36) :
  draw_triangle(count*10, 
                turtle.VALID_COLORS[count % len(turtle.VALID_COLORS)],
                count)

# %% [markdown]
# I really like the fun things we can do with our new ``draw_triangle()`` function, but I miss how the old function was so simple to call. Remember how you could just call ``draw_triangle()`` and turtle would draw a simple, white triangle without having to worry about the telling it a size, colour or turn?
#
# Wouldn't it be great if our triangle function could do all the cool stuff if we passed it parameters, but could also just draw a nice simple triangle if we didn't pass any parameters?
#
# Well, it can &ndash; if we define the function with _default parameter values_. It works like this:

# %%
# A triangle function twith default parameter values.
def draw_triangle(side_length=30, colour='yellow', turn=30) :
  # Set the colour
  turtle.color(colour)
  
  # Turn the turtle right
  turtle.right(turn)

  # Use a loop to draw each side and turn at each corner
  for count in range(3) :
    turtle.forward(side_length)   # Move forward by the given length
    turtle.right(120)

# %%
# Clear the canvas
turtle.initializeTurtle()

# Test calling the function without parameters
draw_triangle()

# %% [markdown]
# Nice and simple! Now let's try passing parameters to the function. But I don't want to pass all the parameters, just colour and turn. To help the function know what values I mean to pass, I will provide them as _named parameters_.

# %%
# Call the function passing named parameters for colour and turn
draw_triangle(turn=75, colour='blue')

# %% [markdown]
# ## Making squares

# %% [markdown]
# <h4>Exercise 29</h4>
#
# Now that you have seen how a function can be used to draw a triangle, it's time fo you to build one that draws a square. You'll start by defining a simple square drawing function called ``draw_square()``, then add some parameters and extra functionality.

# %%
# Write a function below called draw_square() that draws a regular square with 
# sides that are 50 units long.

# %%
# Run this cell to test your function
turtle.initializeTurtle()
draw_square()

# %% [markdown]
# Now add the following parameters to your square drawing function:
# * **side_length**: the length of each side of the square;
# * **colour**: the colour of the square;
# * **turn**: how many degrees turtle must turn before starting to draw the square.
#
# Give each parameter the following default values:
# * side_length=30
# * colour= (_choose your favourite colour_)
# * turn=45

# %%
# Copy your draw_square() function from above and paste it below. Then modify 
# the code to draw a square based on the parameters. Don't forget to add the 
# default values!

# %%
# Run this cell to test your function
import random
turtle.initializeTurtle()

draw_square()   # This will draw a square of size 30 at a 45 degree angle in your favourite colour.

for count in range(18) :
  draw_square(side_length=random.randint(20,60),
              colour=turtle.VALID_COLORS[random.randint(0,len(turtle.VALID_COLORS)-1)],
              turn=random.randint(15,30))

# %% [markdown]
# Great! Your ``draw_square()`` function can draw lots of squares of different sizes, colours and angles. But one limitation it has is that all the quares start at the same place. Wouldn't it be amazing if you could tell the square to start at a particular place on the canvas?
#
# Turtle actually knows how to jump to a splace on the canvas. If you want her to go to a locaton 100 units across and 145 units down, call the function: ``turtle.goto(100, 145)``, and turtle will jump immediately to that location. But be careful! If turtle's pen stays down, she will draw a line from where she started to the new location.
#
# In the final bit of this exercise, modify your square drawing function again to add a parameter called ``location`` that is a tuple of the coordinates where you want turtle to start drawing the square. By default the location will be (100,100).
#
# Here is what your function definition should look like:
# ```python
# def draw_square(side_length=30, colour='red', turn=45, location=(100, 100)) :
# ```
#
# Using this definition, modify your ``draw_square()`` code so that it starts drawing a square at the coordinates given in the ``location`` tuple parameter.

# %%
# Copy the code from your draw square() function and paste it below. Use the 
# function definition provided below and modify your code.

def draw_square(side_length=30, colour='red', turn=45, location=(100, 100)) :
  # Paste your code below, then modify it.
  #
  # HINT: Don't forget to use penup() and pendown() to prevent turtle from 
  #   scribbling across the screen!

# %%
# Run this cell to test your function
import random
turtle.initializeTurtle()

draw_square()   # This will draw a square with the default parameters at (100,100)

# This should create a random trail of colourful squares across your canvas
for count in range(18) :
  draw_square(side_length=random.randint(20,60),
              colour=turtle.VALID_COLORS[random.randint(0,len(turtle.VALID_COLORS)-1)],
              turn=random.randint(15,30),
              location=(count*20 +120, count*15 + 110))

# %% [markdown]
# # **Polygon factory**

# %% [markdown]
# With all the squares and triangles that you and turtle have been making together, you have developed a great reputation around the world for the quality of your shapes. You begin to receive lots of inquiries about whether you can make more shapes &ndash; pentagons, hexagons and nonagons! &ndash; and there are customers who are willing to pay if you will take their orders!!
#
# So you and turtle decide to go into business together. But to be able to fulfill all the orders, you will need to build a polygon factory.
#
# A polygon factory is a function that can produce a regular polygon of any number of sides, in any size and colour. It can also place them on the canvas at any specified location, turned at any angle that a customer wants.

# %% [markdown]
# <h4>Exercise 30</h4>
#
# This shouldn't be too hard. After all, you recently developed a similar function for squares, and earlier in this discovery you created a polygon machine. You will now combine what you've learnt to build a polygon factory.

# %% [markdown]
# ## The ``draw_polygon()`` function
#
# Your first task is to turn your polygon machine code from Exercise 27 into a function. Start by copying your final code from Exercise 27 and pasting it in the code cell below.

# %%
# Copy and paste your final code from Exercise 27 (polygon machine) below. Run 
# the code to help yourself remember how it works.

# %%
# Set these variables for the polygon you want to draw.
poly_sides = 3      # Number of sides in the polygon
side_length = 20    # Set this to however long we want each side to be
corners = 3         # Number of corners in the polygon
poly_turn = 120     # Number of degrees that the turtle needs to turn at each corner
side_colour = 'yellow'  # The colour we've chosen for the polygon.

# Start by clearing the canvas
turtle.initializeTurtle()

# Set the colour
turtle.color(side_colour)

# Below, write a loop and block of code to draw the polygon 
# (Hint: You can do this with three lines of code.)

# %% [markdown]
# In the next code cell, you will create the ``draw_polygon()`` function. Copy and paste any code from the previous cell that will be useful in your new function.
#
# Here are a few question to think about:
#
# * Consider each line of code carefully... ask yourself what it does and whether that line is needed for the function that you are creating.
# * How might the line code might need to be modified for the new function?
# * Do the variables above make sense for your new function? What do you think takes their place inside a function?

# %%
# Code the draw_polygon() function here. The definition line is already given.
#
# Default parameter values have not been set, but you should add your own.

def draw_polygon(num_sides, side_length, turn, colour, location) :
  # Add code to implement this function below.

# %%
import math

def draw_polygon(num_sides=3, side_length=40, turn=30, colour='orange', location=(100,100)) :
  turtle.penup()
  turtle.goto(location[0], location[1])
  turtle.pendown()

  turtle.color(colour)
  turtle.right(turn - (turtle.turtle_degree + 90))
  
  for count in range(num_sides) :
    turtle.forward(side_length)
    turtle.right(math.trunc(360 / num_sides))

# %%
# Run this cell to test your function
import random
turtle.initializeTurtle(initial_speed=10)   # Set turtle to max speed!

draw_polygon()   # This will draw a polygon using your default parameters

# This should create a random trail of colourful polygons across your canvas
for count in range(18) :
  draw_polygon(num_sides=random.randint(3,5),
               side_length=random.randint(20,60),
               colour=turtle.VALID_COLORS[random.randint(0,len(turtle.VALID_COLORS)-1)],
               turn=random.randint(15,30),
               location=(count*20 +120, count*15 + 110))

# %% [markdown]
# Well done! Now that your polygon factory is up and running, the customer orders start pouring in. Customers send you their shape requirements, telling you the number of sides they need, the size and colour that they want, and the orientation of the shapes.
#
# Here are some examples of the orders you receive:
#
# |Order #|Number<br/>of Sides|Side Length<br/>(units)|Orientation<br/>(&deg;)|Colour|
# |---|---|---|---|---|
# |10|4|34|45|white|
# |11|3|72|120|blue|
# |12|3|34|30|white|
# |17|5|50|90|green|
# |21|4|51|45|yellow|
# |26|4|48|45|purple|
# |37|5|34|270|orange|
# |38|3|48|30|purple|
# |39|4|33|0|red|
# |62|3|33|180|red|
# |73|3|51|0|white|
# |82|5|72|270|blue|

# %% [markdown]
# To manage all the orders, you store each one in a tuple and store all the order tuples in a list called ``order_list``. This makes it easier to pass the correct values to for each polygon to your polygon factory. Here's what the order list looks like for the orders above:

# %%
# Customer orders organized into a list of tuples

order_list = [
              (4, 34, 45, 'white'),
              (3, 72, 120, 'blue'),
              (3, 34, 30, 'white'),
              (5, 50, 90, 'green'),
              (4, 51, 45, 'yellow'),
              (4, 48, 45, 'purple'),
              (5, 34, 270, 'orange'),
              (3, 48, 30, 'purple'),
              (4, 33, 0, 'red'),
              (3, 33, 180, 'red'),
              (3, 51, 0, 'white'),
              (5, 72, 270, 'blue')
]

# %% [markdown]
# Run the cells above and below to see how the customer orders look.

# %%
import math

# Define a function to display 12 orders nicely on the canvas
def display_orders(order_items, page=0) :
  turtle.initializeTurtle(initial_speed=10)

  # Find out how many orders are in the order list
  num_orders = len(order_items)

  # Draw each order in a separate location on the canvas
  for y in range(3) :
    for x in range(4) :
      # Calculate the index of the next order
      order_index = (page * 12) + (y * 4) + x

      # Break out of this loop if the index is beyond the number of orders
      if order_index >= num_orders :
        break

      # Retrieve the next order
      order = order_items[order_index]

      # Calculate the next display location and draw the polygon
      location = ((x * 180) + 100, (y * 150) + 100)
      draw_polygon(num_sides=order[0], side_length=order[1], turn=order[2], colour=order[3], location=location)


# Call the function with our order list to display them
display_orders(order_list)

# %% [markdown]
# ## Ordering from a catalogue
#
# Your shape making business is off to a good start. Customers are returning to place new orders, but some of them also make some suggestions.
#
# For example, they like having the ability to customize their shape, but they find it too much work to specify everything in exact numbers. They tell you that life would be easier for them if they could order a "medium triangle" or a "large square" or "small pentagon".
#
# Another popular bit of feedback is that rather than ordering each shape individually, they would like to be able to order them in quantity. Like ordering "3 medium squares" and "6 small pentagons" and "two large triangles".
#
# In reviewing the orders above, you also notice a couple of things.
# * What do you notice about the orientation (turn) of the shapes?
# * Do you notice anything about the sizes and colours?

# %% [markdown]
# You decide that to make ordering simpler for your customers, you will offer them a catalogue of available shape configurations, and an easy way to build an order with many qunatities of different shapes.
#
# **Catalogue**
#
# You want to provide your customers with a catalogue called ``shape_catalogue`` that allos them to find a specific shape configuration. For example, if they want a medium-sized triangle, they can find it using ``shape_catalogue['triangle-medium']``. Or they could be looking for a large square, which they could find in the catalogue with ``shape_catalogue['square-large']``.
# * What will you use to define ``shape_catalogue``?<br/>(_e.g. should it be a string, a list, a map, a tuple or something else?_)
# * When the customer looks up the shape in the catalogue, what information should the catalogue contain about the shape?<br/>(_Hint: think about the ``order_list`` example and what it contained._)
#
# In the code cell below, define a ``shape_catalogue`` containing a small and large triangle, a medium and large square, and a small and medium pentagon. The triangles should each have options to point up, down, left or right. The pentagons should either point up or down. Finally add an option for diamonds (which are really just squares tilted at an angle). Here's a list to make it easier:
#
# * triangle-small-up
# * triangle-small-down
# * triangle-small-left
# * triangle-small-right
# * triangle-large-up
# * triangle-large-down
# * triangle-large-left
# * triangle-large-right
# * square-medium
# * square-large
# * pentagon-small-up
# * pentagon-small-down
# * pentagon-medium-up
# * pentagon-medium-down
# * diamond-medium
# * diamond-large

# %%
# Define your shape_catalogue below
shape_catalogue =

# %% [markdown]
# **Order builder**
#
# To make it easy for customers to order their shapes, you decide to create an order builder. Define a ``build_order()`` function that takes the following parameters and returns an list of items in their order.
#
# * **shape_selection:** an item that is found in the ``shape_catalogue``
# * **colour:** the colour of this shape that the customer wants
# * **quantity:** the number of these items that the customer is ordering.
# * **existing_order:** an order that the customer has already started, and which they want to add to. This can also be an empty list ``[]`` if no order has been started.
#
# ``build_order()`` returns an order, which is a list of all the items tuple of (shape_selection, colour, quantity) that have been added to this order.
#
# The function definition is provided below. You just need to add the code needed to make it work.

# %%
# Add code to complete the build_order() function.
def build_order(shape_selection, colour, quantity, existing_order=[]) :
  # Code the function below. Return an order that is a list of tuples of 
  # (shape_selection, colour, quantity)

# %% [markdown]
# ## Manufacture the shapes
#
# You've built an easy way for customers to place an order from your catalogue, just like they asked. The final step is to manufacture the order and show it to them.
#
# Create a function below called ``manufacture_order()`` that takes ``customer_order`` that was returned from calling ``build_order()``. Use ``display_orders()`` to display the all the manufactured in the order. The function must return the number of items that were successfully manufactured.
#
# The structure of the ``manufacture_order()`` fuction is provided below. All you need to do is fill in the missing code suggested by the comment lines.

# %%
# Code the manufacture_order function below.

def manufacture_order(customer_order, page=0) :
  shapes_to_make = []

  for order_item in customer_order :
    # Retrieve the shape selection from order_item

    # Retrieve the colour from order_item

    # Retrieve the quantity from order_item

    # Look up the shape in the catalogue to find its recipe

    # Repeat as many times as the quantity:
      # Add the shape recipe and the colour to the shapes_to_make list

  # Now you should have all the shapes from customer_order in shapes_to_make.
  # Calling display_orders will display all the manufactured shapes.
  display_orders(shapes_to_make, page)

  # You need to return the number of shapes that were manufactured in this order.

# %% [markdown]
# Run the code cell below to test out your new polygon factory catalogue ordering system. The test code will build a customer order from the catalogue, then pass that order for manufacturing. If everything works well, it should display the completed order!

# %%
# "Shifty Shapes" is one of the first customers to try your new catalogue
# ordering system. Here is the order they place:

# Two large purple diamonds
shifty_order = build_order(shape_catalogue['diamond-large'], 'purple', 2)

# Three small yellow triangles facing up
shifty_order = build_order(shape_catalogue['triangle-small-down'], 'yellow', 3, shifty_order)

# Two medium-sized blue triangles pointing left
shifty_order = build_order(shape_catalogue['triangle-medium-left'], 'blue', 2, shifty_order)

# Two medium-sized red triangles pointing right
shifty_order = build_order(shape_catalogue['triangle-medium-right'], 'red', 2, shifty_order)

# Two small green pentagons pointing down
shifty_order = build_order(shape_catalogue['pentagon-small-down'], 'green', 2, shifty_order)

# One medium orange square
shifty_order = build_order(shape_catalogue['square-medium'], 'orange', 1, shifty_order)


# Let's print and review the order
print("Here is the order:\n%s" % str(shifty_order))


# The order is passed to your factory for manufacturing.
shapes_made = manufacture_order(shifty_order)

print("Order ready. The factory made %i shapes." % (shapes_made))
