# %%
# !pip3 install ColabTurtle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/PySomani/master
# Out:
# /content/gdrive/My Drive/PySomani/master

# %%
import xodraw

# %%
xodraw.drawBoard()
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="90" y1="30" x2="90" y2="210" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150" y1="30" x2="150" y2="210" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="30" y1="90" x2="210" y2="90" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="30" y1="150" x2="210" y2="150" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=hidden transform="rotate(180,210,150) translate(210, 150)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
game = []
game.append((1,1,'X'))

# %%
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="90" y1="30" x2="90" y2="210" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150" y1="30" x2="150" y2="210" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="30" y1="90" x2="210" y2="90" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="30" y1="150" x2="210" y2="150" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="102" y1="102" x2="138" y2="138" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="138" y1="102" x2="102" y2="138" stroke-linecap="round" style="stroke:red;stroke-width:4"/>
#
#       <g visibility=hidden transform="rotate(180,102,138) translate(102, 138)">
#         <circle stroke="red" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:red;stroke:red;stroke-width:2"/>
#       </g>
#
# ...

# %%
game.append((0,0,'O'))

# %%
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((2,2,'X'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((0,1,'O'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((0,2,'X'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((2,0,'O'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((2,1,'X'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game.append((1,0,'O'))
xodraw.drawGame(game)
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
xodraw.drawWin(startPos=(0,0), endPos=(2,0))
# Out:
#       <svg width="240" height="240">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
game
# Out:
# [(1, 1, 'X'),
#  (0, 0, 'O'),
#  (2, 2, 'X'),
#  (0, 1, 'O'),
#  (0, 2, 'X'),
#  (2, 0, 'O'),
#  (2, 1, 'X'),
#  (1, 0, 'O')]
